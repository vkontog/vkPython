# %%
#! pip install zeep
#! pip install dict2xml
#! pip install pycryptodome
#!pip install cryptography

# %%
import requests
import datetime
from datetime import date
import hashlib
import xml.etree.ElementTree as ET

# %%
from cryptography.hazmat.primitives.asymmetric import rsa, padding
from cryptography.hazmat.primitives import serialization, hashes
from cryptography.hazmat.backends import default_backend

# %%
private_key_str = """
-----BEGIN PRIVATE KEY-----

-----END PRIVATE KEY-----"""

# %%
def encrypt_string(plain_text, private_key_str):
    private_key = serialization.load_pem_private_key(
        private_key_str.encode('utf-8'),
        password=None,
        backend=default_backend()
    )

    cipher_text = private_key.public_key().encrypt(
        plain_text.encode('utf-8'),
     
        padding.OAEP(
            mgf=padding.MGF1(algorithm=hashes.SHA256()),
            algorithm=hashes.SHA256(),
            label=None
        )
    )
    
        
    
    return cipher_text

# %%
#d1 = datetime.datetime.strptime("2023-05-09","%Y-%m-%d").strftime('%Y-%m-%d') + "T" + datetime.datetime.strptime("18:53:00","%H:%M:%S").strftime('%H-%M-%S')
d1 = date.today().strftime('%Y-%m-%d') + "T" + datetime.datetime.now().strftime('%H:%M:%S')

# %%
RequestData ='<System>1</System><RequestDateTime>'+ d1 + '</RequestDateTime><InitiationDateFrom>2023-04-04T00:00:00</InitiationDateFrom>'
#RequestData ='<System>1</System><RequestDateTime>'+ d1 + '</RequestDateTime><ApplicantVatNumber>040473332</ApplicantVatNumber>'

# %%
print(RequestData)
# Out:
# <System>1</System><RequestDateTime>2023-05-17T16:54:33</RequestDateTime><InitiationDateFrom>2023-04-04T00:00:00</InitiationDateFrom>

# %%
RequestData_hashed = hashlib.sha256(RequestData.encode(encoding = 'UTF-8', errors = 'strict')).hexdigest()

# %%
print(RequestData_hashed)
# Out:
# 155f853593f3d9dbe556c1c786cc385d70ecfa1c0da23de1bed51be364b65a3e

# %%
EncryptedRequestDataHash = encrypt_string(RequestData,private_key_str)

# %%
#4462e0ad97e7d150d7323ffdf0af2d3a2d8d670f420951814929246122cd9eb9
#https://emn178.github.io/online-tools/sha256.html
#https://www.devglan.com/online-tools/rsa-encryption-decryption

# %%
#use the above site till you figure the problem
EncryptedRequestDataHash = ''

# %%
url = "https://www1.gsis.gr:443/dsae2/wsgsis/iifservices/GetApplicationsBinding"

# %%
payload = """<soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:iif="http://iif.gsis.gr/services/iif">
   <soap:Header/>
   <soap:Body>
      <iif:GetApplicationsRequest>
         <iif:InstitutionVatNumber>800874006</iif:InstitutionVatNumber>
         <iif:RequestData>{0}</iif:RequestData>
         <iif:EncryptedRequestDataHash>{1}</iif:EncryptedRequestDataHash>
      </iif:GetApplicationsRequest>
   </soap:Body>
</soap:Envelope>""".format(RequestData.replace("<","&lt;"),EncryptedRequestDataHash)

# %%
print(payload)

# %%
response = requests.request("POST", url, data=payload)

# %%
print(response.text)
# Out:
# <?xml version='1.0' encoding='UTF-8'?><S:Envelope xmlns:S="http://www.w3.org/2003/05/soap-envelope"><S:Header><WorkContext xmlns="http://oracle.com/weblogic/soap/workarea/">rO0ABXdLABd3ZWJsb2dpYy5hcHAuSUlGX1NlcnZlcgAAANYAAAAjd2VibG9naWMud29ya2FyZWEuU3RyaW5nV29ya0NvbnRleHQAAzE0OAAA</WorkContext></S:Header><S:Body><GetApplicationsResponse xmlns="http://iif.gsis.gr/services/iif"><Applications><Application><System>1</System><ApplicationNumber>222149</ApplicationNumber><ApplicantVatNumber>052731537</ApplicantVatNumber><InitiationDate>2023-04-04T00:31:58</InitiationDate><SubmissionDate xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:nil="true"/><DataRequestDate>2023-04-04T00:40:33</DataRequestDate><CutOffDate xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:nil="true"/><Status>1</Status><StatusStartDate>2023-04-04T00:31:58</StatusStartDate><StatusExpectedEndDate xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:nil="true"/><CompletionReason xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:nil="true"/></Application><Application><System>1</System><ApplicationNumber>222151</ApplicationNumber><ApplicantVatNumber>155229138</ApplicantVatNumber><InitiationDate>2023-04-04T04:35:06</InitiationDate><SubmissionDate xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:nil="true"/><DataRequestDate>2023-04-04T04:41:49</DataRequestDate><CutOffDate xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:nil="true"/><Status>1</Status><StatusStartDate>2023-04-04T04:35:06</StatusStartDate><StatusExpectedEndDate xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:nil="true"/><CompletionReason xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:nil="true"/></Application><Application><System>1</System><ApplicationNumber>222153</ApplicationNumber><ApplicantVatNumber>074221585</ApplicantVatNumber><InitiationDate>2023-04-04T06:27:30</InitiationDate><SubmissionDate xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:nil="true"/><DataRequestDate>2023-04-06T05:57:06</DataRequestDate><CutOffDate xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:nil="true"/><Status>1</Status><StatusStartDate>2023-04-04T06:27:30</StatusStartDate><StatusExpectedEndDate xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:nil="true"/><CompletionReason xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:nil="true"/></Application><Application><System>1</System><ApplicationNumber>222154</ApplicationNumber><ApplicantVatNumber>115564690</ApplicantVatNumber><InitiationDate>2023-04-04T06:44:35</InitiationDate><SubmissionDate xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:nil="true"/><DataRequestDate>2023-04-06T19:49:02</DataRequestDate><CutOffDate xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:nil="true"/><Status>1</Status><StatusStartDate>2023-04-04T06:44:35</StatusStartDate><StatusExpectedEndDate xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:nil="true"/><CompletionReason xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:nil="true"/></Application><Application><System>1</System><ApplicationNumber>222155</ApplicationNumber><ApplicantVatNumber>110718100</ApplicantVatNumber><InitiationDate>2023-04-04T06:57:53</InitiationDate><SubmissionDate xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:nil="true"/><DataRequestDate>2023-05-16T09:11:47</DataRequestDate><CutOffDate xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:nil="true"/><Status>1</Status><StatusStartDate>2023-04-04T06:57:53</StatusStartDate><StatusExpectedEndDate xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:nil="true"/><CompletionReason xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:nil="true"/></Application><Application><System>1</System><ApplicationNumber>222157</ApplicationNumber><ApplicantVatNumber>034565941</ApplicantVatNumber><InitiationDate>2023-04-04T08:00:39</InitiationDate><SubmissionDate xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:nil="true"/><DataReq ...
